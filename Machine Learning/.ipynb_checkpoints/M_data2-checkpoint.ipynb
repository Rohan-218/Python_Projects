# %%
import pandas as pd                
#from sklearn.tree import DecisionTreeClassifier  
import joblib as jb                 

# music_data = pd.read_csv('music.csv')
# x = music_data.drop(columns=['genre'])  
# y = music_data['genre']                  

# model = DecisionTreeClassifier()
# model.fit(x, y)

# Save the trained model to a file using joblib
# jb.dump(model, 'music_model')
model = jb.load('music_model')
predictions = model.predict([ [21,1] , [22,0] ])
predictions
# Out:
# C:\Users\rohan\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['HipHop', 'Dance'], dtype=object)
