# %%
import pandas as pd                    
from sklearn.tree import DecisionTreeClassifier as dst  
import sklearn.tree               


music_data = pd.read_csv('music.csv')
x = music_data.drop(columns=['genre'])   
y = music_data['genre']                  

model = dst()
model.fit(x, y)

# Export the decision tree visualization to a Graphviz dot file
tree.export_graphviz(model, out_file='music-recommender.dot',
                     feature_names=['age', 'gender'],  # Specify feature names for visualization
                     class_names=sorted(y.unique()),   # Specify class names for visualization
                     label='all',                     # Display all nodes, including those not labeled
                     rounded=True,                    # Round the corners of nodes
                     filled=True)                     # Fill nodes with colors based on majority class
